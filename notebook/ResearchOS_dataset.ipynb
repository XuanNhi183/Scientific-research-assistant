# %%
try:
    from google.colab import userdata
    github_token = userdata.get("GITHUB_TOKEN")
except Exception:
    import os
    github_token = os.environ.get("GITHUB_TOKEN", "")

# !git clone https://{github_token}@github.com/XuanNhi183/Scientific-research-assistant.git
# Out:
# Cloning into 'Scientific-research-assistant'...
# remote: Enumerating objects: 794, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 794 (delta 43), reused 67 (delta 23), pack-reused 693 (from 1)
# Receiving objects: 100% (794/794), 386.56 MiB | 23.74 MiB/s, done.
# Resolving deltas: 100% (295/295), done.
# Updating files: 100% (297/297), done.

# %%
# !git pull
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# # Starting

# %%
import os
os.chdir('/content/Scientific-research-assistant')
# %cd /content/Scientific-research-assistant
# Out:
# /content

# %%
# !uv run python scripts/test_ingestion.py data/raw_papers/paper_020.pdf

# %% [markdown]
# # Generation

# %%
# !uv pip install --system -r pyproject.toml
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 177 packages in 2.79s
# Prepared 38 packages in 4.85s
# Uninstalled 6 packages in 643ms
# Installed 38 packages in 118ms
#  + anthropic==0.46.0
#  + bcrypt==5.0.0
#  + build==1.5.0
#  + cfgv==3.5.0
#  + chromadb==1.5.9
#  + distlib==0.4.3
#  + durationpy==0.10
#  + filetype==1.2.0
#  + ftfy==6.3.1
#  - huggingface-hub==1.18.0
#  + huggingface-hub==0.36.2
#  + identify==2.6.19
#  + kubernetes==36.0.2
#  + langchain-text-splitters==1.1.2
#  + markdown2==2.5.5
#  + markdownify==1.2.2
#  + marker-pdf==1.10.2
#  + nodeenv==1.10.0
#  + npm==0.1.1
#  + onnxruntime==1.26.0
#  - openai==2.41.0
#  + openai==1.109.1
#  - opencv-python-headless==4.13.0.92
#  + opencv-python-headless==4.11.0.86
#  + opentelemetry-exporter-otlp-proto-grpc==1.38.0
#  + optional-django==0.1.0
#  + overrides==7.7.0
#  + pdftext==0.6.3
#  - pillow==11.3.0
#  + pillow==10.4.0
#  + pre-commit==4.6.0
#  + pybase64==1.4.3
#  + pymupdf==1.27.2.3
#  + pypdfium2==4.30.0
# ...

# %%
# !ipython notebook/QA_Dataset_Generator.ipynb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.1/25.1 MB 64.0 MB/s eta 0:00:00
# ...
# Using Python 3.12.13 environment at: /usr
# Resolved 178 packages in 121ms
#   × Failed to build `researchrag @ file:///content/Scientific-research-assistant`
#   ├─▶ The build backend returned an error
#   ╰─▶ Call to `setuptools.build_meta:__legacy__.build_wheel` failed (exit
#       status: 1)
#
#       [stderr]
#       error: Multiple top-level packages discovered in a flat-layout:
#       ['img', 'data', 'config', 'prompt', 'service', 'schemas', 'notebook',
#       'frontend', 'dataset_builder'].
#
#       To avoid accidental inclusion of unwanted files or directories,
#       setuptools will not proceed with this build.
#
#       If you are trying to create a single distribution with multiple packages
#       on purpose, you should not rely on automatic discovery.
#       Instead, consider the following options:
#
#       1. set up custom discovery (`find` directive with `include` or
# ...

# %% [markdown]
# # Read dataset

# %%
import pandas as pd
data = pd.read_json('./data/dataset.jsonl', lines=True)
data.head(20)

# %% [markdown]
# # Push HF

# %%
# !powershell -ExecutionPolicy ByPass -c "irm https://hf.co/cli/install.ps1 | iex"
# !hf auth login
# !hf upload xunnhi/QA-Dataset-Generator ./data/dataset.jsonl --repo-type dataset

# %%
# !git config --global user.email "colab-bot@example.com"
# !git config --global user.name "Colab Bot"

try:
            from google.colab import userdata
            github_token = userdata.get("GITHUB_TOKEN")
        except Exception:
            github_token = os.environ.get("GITHUB_TOKEN", "")

if github_token:
    repo_url = f"https://{github_token}@github.com/XuanNhi183/Scientific-research-assistant.git"

    # !git add .
    # !git commit -m "chore: auto-update QA dataset from Colab"

    # !git push {repo_url} HEAD:main
    print("\nSuccessfully update to GitHub!")
else:
    print("Missing COLAB_TOKEN in environment variables. Cannot push to GitHub.")
